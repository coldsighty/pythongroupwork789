# %%
import pandas as pd
dfItaly = pd.read_excel('Italy Data.xlsx')
dfUSA = pd.read_excel('USA Data.xlsx')
print(dfItaly)
print(dfUSA)
# Out:
#     International Financial Statistics (IFS) Unnamed: 1  \
# 0                                        NaN        NaN
# 1                                      Italy   Jan 1960
# 2                                      Italy   Feb 1960
# 3                                      Italy   Mar 1960
# 4                                      Italy   Apr 1960
# ..                                       ...        ...
# 368                                    Italy   Aug 1990
# 369                                    Italy   Sep 1990
# 370                                    Italy   Oct 1990
# 371                                    Italy   Nov 1990
# 372                                    Italy   Dec 1990
#
#                                           Unnamed: 2  \
# 0    Economic Activity, Industrial Production, Index
# 1                                            31.1343
# 2                                            32.6027
# 3                                            33.7129
# ...
